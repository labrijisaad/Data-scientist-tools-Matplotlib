# %% [markdown]
# <table align="center">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/labrijisaad/Data-scientist-tools-Matplotlib"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab</a>
#   </td>
# </table>
#
#
# > 🙌 Notebook made by [@labriji_saad](https://github.com/labrijisaad) inspired by the work of [ageron](https://github.com/ageron).

# %% [markdown]
# ## 🛠️   Data scientist tools - `matplotlib` :
# > We will see in this **`hands-on training notebook`** how to use the **`matplotlib`** library to plot beautiful graphs in **python**.

# %% [markdown]
# ### 📚   `Table of Contents` :
#
# > 1️⃣  **`Plotting your first graph`**
#
# > 2️⃣  **`Line style and color`**
#
# > 3️⃣  **`Saving a figure`**
#
# > 4️⃣  **`Subplots`**
#
# > 5️⃣  **`Multiple figures`**
#
# > 6️⃣  **`Pylab vs Pyplot vs Matplotlib`**
#
# > 7️⃣  **`Drawing text`**
#
# > 8️⃣  **`Legends`**
#
# > 9️⃣  **`Non linear scales`**
#
# > 1️⃣0️⃣  **`Ticks and tickers`**
#
# > 1️⃣1️⃣  **`Polar projection`**
#
# > 1️⃣2️⃣  **`3D projection`**
#
# > 1️⃣3️⃣  **`Scatter plot`**
#
# > 1️⃣4️⃣  **`Lines`**
#
# > 1️⃣5️⃣  **`Histograms`**
#
# > 1️⃣6️⃣  **`Images`**
#
# > 1️⃣7️⃣  **`Animations`**
#
# > 1️⃣8️⃣  **`What next?`**

# %% [markdown]
# ### 1️⃣   `Plotting your first graph` :

# %% [markdown]
# > First let's make sure that this notebook works well in both **`python 2`** and **`python 3`** :

# %%
from __future__ import division, print_function, unicode_literals

# %% [markdown]
# >  We need to import the **`matplotlib`** library :

# %%
# Importing the matplotlib library :
import matplotlib

# %% [markdown]
# > `Matplotlib` can output graphs using various backend graphics libraries, such as Tk, wxPython, etc.
#
# > When running python using the command line, the graphs are typically shown in a separate window.
#
# > In a Jupyter notebook, we can simply output the graphs within the notebook itself by running the **`%matplotlib inline`** magic command.

# %%
# %matplotlib inline

# %% [markdown]
# > Now let's plot our first graph! :)

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 4, 9, 5, 3]) # (1, 0), (2, 1), (4, 2), (9, 3), (5, 4), (3, 5)
plt.show()

# %% [markdown]
# > If the **`plot`** function is given one **array of data**, it will use it as the coordinates on the vertical axis, and it will just use each data point's index in the array as the horizontal coordinate.
#
# > We can also provide two arrays :
# >    - one for the horizontal axis **`x`**,
# >    - and the second for the vertical axis **`y`**

# %%
plt.plot([-3, -2, 5, 0], [1, 6, 4, 3]) # (-3, 1), (-2, 6), (5, 4), ...
plt.show()

# %% [markdown]
# > The axes automatically match the extent of the data.
#
# > We would like to give the graph a bit more room, so let's call the **`axis`** function to change the extent of each axis :
#
# > **`.axis([xmin, xmax, ymin, ymax])`**.

# %%
plt.plot([-3, -2, 5, 0], [1, 6, 4, 3]) # (-3, 1), (-2, 6), (5, 4), ...
plt.axis([-4, 6, 0, 7]) # horizental(-4 >--< 6) , vertical(0 >--< 7)
plt.show()

# %% [markdown]
# > Now, let's plot a mathematical function.
# > We use NumPy's **`linspace`** function to create an array **`x`** containing **500** floats ranging from **-2** to **2**, then we create a second array **`y`** computed as the square of **`x`**.

# %%
import numpy as np
x = np.linspace(-2, 2, 500)
y = x**2

plt.plot(x, y)
plt.show()

# %% [markdown]
# > That's a bit dry, let's add a title, and **x** and **y** labels, and draw a grid.

# %%
plt.plot(x, y)
plt.title("Square function")
plt.xlabel("x")
plt.ylabel("y = x**2")
plt.grid(True)
plt.show()

# %% [markdown]
# ### 2️⃣   ` Line style and color` :

# %% [markdown]
# > By default, **`matplotlib`** draws a line between consecutive points.

# %%
plt.plot([0, 100, 100, 0, 0, 100, 50, 0, 100],
         [0, 0, 100, 100, 0, 100, 130, 100, 0]) # (0, 0), (0, 100), (100, 100) ...

plt.axis([-10, 110, -20, 140]) # horizental(-10 >--< 100) , vertical(-20 >--< 140)
plt.show()

# %% [markdown]
# > We can pass a 3rd argument to change the line's style and color.
#
# > For example **`"g--"`** means **"green dashed line"** :

# %%
plt.plot([0, 100, 100, 0, 0, 100, 50, 0, 100], 
         [0, 0, 100, 100, 0, 100, 130, 100, 0], "g--")

plt.axis([-10, 110, -10, 140])
plt.show()

# %% [markdown]
# > We can plot multiple lines on one graph very simply:
# > - just pass `x1, y1, [style1], x2, y2, [style2], ...`
#
# > For example :

# %%
plt.plot([0, 100, 100, 0, 0], 
         [0, 0, 100, 100, 0], "r-", 
         [0, 100, 50, 0, 100], 
         [0, 100, 130, 100, 0], "g--")

plt.axis([-10, 110, -10, 140])
plt.show()

# %% [markdown]
# > Or we can simply call **`plot`** multiple times before calling **`show`**.

# %%
plt.plot([0, 100, 100, 0, 0], 
         [0, 0, 100, 100, 0], "r-")

plt.plot([0, 100, 50, 0, 100], 
         [0, 100, 130, 100, 0], "g--")

plt.axis([-10, 110, -10, 140])
plt.show()

# %% [markdown]
# > We can also draw simple points instead of lines.
#
# > Here's an example with green dashes, red dotted line and blue triangles :

# %%
x = np.linspace(-1.4, 1.4, 30)
plt.plot(x, x, 'g--', 
         x, x**2, 'r:', 
         x, x**3, 'b^')
plt.show()

# %% [markdown]
# > The plot function returns a list of **`Line2D`** objects (one for each line).
#
# > Check out [the documentation](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.plot) for the full list of style & color options.

# %%
x = np.linspace(-1.4, 1.4, 30)

line1, line2, line3 = plt.plot(x, x, 'g--',   # line 1 == green line
                               x, x**2, 'r:', 
                               x, x**3, 'b^')
line1.set_linewidth(3.0)
line1.set_dash_capstyle("round")
line3.set_alpha(0.2)
plt.show()

# %% [markdown]
# > - **`set_alpha()`** function in axes module of matplotlib library is used to set the alpha value used for **blending**.

# %% [markdown]
# ### 3️⃣   `Saving a figure` :
# > Saving a figure to disk is as simple as calling **`.savefig()`** with the name of the file (or a file object).
#
# > The available image formats depend on the graphics backend we use.

# %%
x = np.linspace(-1.4, 1.4, 30)

plt.plot(x, x**2)
plt.savefig("my_square_function.png", 
            transparent=True)

# %% [markdown]
# ### 4️⃣   `Subplots` :
# > A matplotlib figure may contain multiple subplots.
#
# >  These subplots are organized in a grid. To create a subplot, we just call the **`subplot`** function, and specify the **number of rows** and **columns** in the figure, and the **index of the subplot** we want to draw on (starting from **1**, then **left** to **right**, and **top** to **bottom**).
#
# > Note that **pyplot** keeps track of the currently active subplot (which we can get a reference to by calling **`plt.gca()`**), so when you call the `plot` function, it draws on the *active* subplot.

# %%
x = np.linspace(-1.4, 1.4, 30)
plt.subplot(2, 2, 1)  # 2 rows, 2 columns, 1st subplot = top left
plt.plot(x, x, 'y_')

plt.subplot(2, 2, 2)  # 2 rows, 2 columns, 2nd subplot = top right
plt.plot(x, x**2, 'r^')

plt.subplot(2, 2, 3)  # 2 rows, 2 columns, 3rd subplot = bottow left
plt.plot(x, x**3, 'b--')

plt.subplot(2, 2, 4)  # 2 rows, 2 columns, 4th subplot = bottom right
plt.plot(x, x**4,  'g:')

plt.show()

# %% [markdown]
# <table>
#     <tbody>
#         <tr>
#             <td>
#                 <font face = "Comic sans MS" size = "3">top left = 1st subplot</font>
#             </td>
#             <td>
#                 <font face = "Comic sans MS" size = "3">top right == 2nd subplot</font>
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 <font face = "Comic sans MS" size = "3">bottom left == 3rd subplot</font>
#             </td>
#             <td>
#                 <font face = "Comic sans MS" size = "3">bottom right == 4th subplot</font>
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# > - Note that **`subplot(223)`** is a shorthand for **`subplot(2, 2, 3)`**.
#
# > - It is easy to create **subplots** that span across multiple grid cells like so :

# %%
plt.subplot(2, 2, 1)  # 2 rows, 2 columns, 1st subplot = top left
plt.plot(x, x, 'y_')

plt.subplot(2, 2, 2)  # 2 rows, 2 columns, 2nd subplot = top right
plt.plot(x, x**2, 'b*')

plt.subplot(2, 1, 2)  # 2 rows, *1* column, 2nd subplot = bottom
plt.plot(x, x**3, 'g>')

plt.show()

# %% [markdown]
# > ```
#   subplot(2, 2, 1) → 2 rows, 2 columns, 1st subplot =  top left
#   subplot(2, 2, 2) → 2 rows, 2 columns, 2nd subplot = top right
#   subplot(2, 2, 1) → 2 rows, 1 columns, 2nd subplot = bottom
#
#
# > - If we need more complex subplot positionning, we can use **`subplot2grid`** instead of **`subplot`**.
# > - We can specify the number of **rows** and **columns** in the grid, then our subplot's position in that grid (top-left = (0,0)), and optionally how many rows and/or columns it spans.
#
# > For example :

# %%
plt.subplot2grid((3,3), (0, 0), rowspan=2, colspan=2)
plt.plot(x, x**2, 'y_')

plt.subplot2grid((3,3), (0, 2))
plt.plot(x, x**3, 'r<')

plt.subplot2grid((3,3), (1, 2), rowspan=2)
plt.plot(x, x**4, 'g*')

plt.subplot2grid((3,3), (2, 0), colspan=2)
plt.plot(x, x**5, 'b_')
plt.show()

# %% [markdown]
# ### 5️⃣   `Multiple figures` :
# > It is also possible to draw multiple figures. Each figure may contain one or more subplots.
#
# > By default, **matplotlib** creates **`figure(1)`** automatically. When we switch figure, **pyplot** keeps track of the currently active **figure** (which you can get a reference to by calling **`plt.gcf()`**), and the active **subplot** of that **figure** becomes the current **subplot**.

# %%
x = np.linspace(-1.4, 1.4, 30)

# Figure 1 :
plt.figure(1)
plt.subplot(211) # 2 rows, 1 column, 1st subplot =  top
plt.title("Square and Cube functions")

plt.plot(x, x**2)
plt.subplot(212) # 2 rows, 1 column, 1st subplot =  bottom
plt.plot(x, x**3)

# Figure 2 :
plt.figure(2, figsize=(10, 5))
plt.subplot(121)  # 1 row, 2 columns, 1st subplot =  left
plt.plot(x, x**4, 'r+')
plt.title("f(x) = x**4")

plt.subplot(122) # 1 row, 2 columns, 1st subplot =  right
plt.plot(x, x**5, 'y<')
plt.title("f(x) = x**5")

# Figure 1 :
plt.figure(1)      # back to figure 1, current subplot is 212 (bottom)
plt.plot(x, -x**3, "r:")

plt.show()

# %% [markdown]
# ### 6️⃣   `Pylab` vs `Pyplot` vs  `Matplotlib` :
#
# > There is some confusion around the relationship between **`pylab`**, **`pyplot`** and **`matplotlib`**.
#
# > It's simple : **`matplotlib`** is the full library, it contains everything including **`pylab`** and **`pyplot`**.
#
# > **`Pyplot`** provides a number of *tools to plot graphs*, including the *state-machine* interface to the underlying object-oriented plotting library.
#
# > **`Pylab`** is a convenience module that imports **`matplotlib.pyplot`** and **`NumPy`** in a single name space.

# %% [markdown]
# ### 7️⃣   `Drawing text` :
# > We can call **`text`** to add text at any location in the graph. We just specify the *horizontal* and *vertical* coordinates and the *texet*, and optionally *some extra attributes*.  Any text in *`matplotlib`* may contain TeX equation expressions.

# %%
x = np.linspace(-1.5, 1.5, 30)
px = 0.8
py = px ** 2

# Plotiong :
plt.plot(x, x ** 2, "b-",  # blue function -> f(x) = x**2
         px, py, "ro"  # red point -> (px, py)
         )

# Text :
plt.text(0, 1.75, "Square function\n$y = x^2$",
         fontsize=18, color='green',
         horizontalalignment="center"
         )
plt.text(px - 0.04, py, "Beautiful point",
         ha="right", weight="heavy"
         )
plt.text(px + 0.09, py - 0.1, "x = %0.2f\ny = %0.2f" % (px, py), 
         rotation=55, color='gray'
         )

plt.show()

# %% [markdown]
# > - Note : **`ha`** is an alias for **`horizontalalignment`**.
#
# > - It is quite frequent to annotate elements of a graph, such as the beautiful point above. The **`annotate`** function makes this easy : just indicate the *location of the point* of interest, and the *position of the text*, plus optionally some extra attributes for the text and the arrow.

# %%
x = np.linspace(-1.5, 1.5, 30)
px = 0.8
py = px ** 2

# Ploting :
plt.plot(x, x ** 2, 
         px, py, "ro")

# Text :
plt.annotate("Beautiful point", xy=(px, py), xytext=(px - 1.3, py + 0.5),
             color="green", weight="heavy", fontsize=14,
             arrowprops={"facecolor": "lightgreen"})

plt.show()

# %% [markdown]
# > We can also add a bounding box around your text by using the **`bbox`** attribute:

# %%
x = np.linspace(-1.5, 1.5, 30)
px = 0.8
py = px ** 2

# Ploting :
plt.plot(x, x ** 2, 
         px, py, "ro")

# Text :
bbox_props = dict(boxstyle="rarrow,pad=0.3", ec="b", lw=2, fc="lightblue")
plt.text(px - 0.2, py, "Beautiful point", bbox=bbox_props, ha="right")

bbox_props = dict(boxstyle="round4,pad=1,rounding_size=0.2", ec="black", fc="#EEEEFF", lw=5)
plt.text(0, 1.5, "Square function\n$y = x^2$", fontsize=20, color='black', ha="center", bbox=bbox_props)

plt.show()

# %% [markdown]
# > Just for fun, if you want an [xkcd](http://xkcd.com)-style plot, just draw within a **`with plt.xkcd()`** section:

# %%
with plt.xkcd():
    x = np.linspace(-1.5, 1.5, 30)
    px = 0.8
    py = px ** 2

    # Ploting :
    plt.plot(x, x ** 2, 
             px, py, "ro")

    # Text :
    bbox_props = dict(boxstyle="rarrow,pad=0.3", ec="b", lw=2, fc="lightblue")
    plt.text(px - 0.2, py, "Beautiful point", bbox=bbox_props, ha="right")

    bbox_props = dict(boxstyle="round4,pad=1,rounding_size=0.2", ec="black", fc="#EEEEFF", lw=5)
    plt.text(0, 1.5, "Square function\n$y = x^2$", fontsize=20, color='black', ha="center", bbox=bbox_props)

    plt.show()

# %% [markdown]
# ### 8️⃣   `Legends` :
# > The simplest way to add a legend is to set a label on all lines, then just call the `legend` function.

# %%
x = np.linspace(-1.4, 1.4, 50)
plt.plot(x, x ** 2, "r--", label="Square function")
plt.plot(x, x ** 3, "g-", label="Cube function")
plt.legend(loc="best")
plt.grid(True)
plt.show()

# %% [markdown]
# ### 9️⃣   `Non linear scales` :
# > **`Matplotlib`** supports non linear scales, such as **logarithmic** or **logit** scales.

# %%
with plt.xkcd():
    x = np.linspace(0.1, 15, 500)
    y = x**3

    plt.figure(1)
    plt.plot(x, y)
    plt.yscale('linear')
    plt.title('linear')
    plt.grid(True)

    plt.figure(2)
    plt.plot(x, y)
    plt.yscale('log')
    plt.title('log')
    plt.grid(True)

    plt.figure(3)
    plt.plot(x, y)
    plt.yscale('logit')
    plt.title('logit')
    plt.grid(True)

    plt.figure(4)
    plt.plot(x, y - y.mean())
    plt.yscale('symlog')
    plt.title('symlog')
    plt.grid(True)

    plt.show()

# %% [markdown]
# ### 1️⃣0️⃣   `Ticks and tickers` :
# > **`Ticks`** are the values used to show specific points on the coordinate axis. It can be a **number** or a **string**. Whenever we plot a graph, the axes adjust and take the default ticks. Matplotlib's default ticks are generally sufficient in common situations but are in no way optimal for every plot.
#
# >The axes have little marks called **`ticks`**.  To be precise, **`ticks`** are the **locations** of the marks (eg. (-1, 0, 1)), **`tick lines`** are the small lines drawn at those locations, **`tick labels`** are the **labels** drawn next to the tick lines, and **`tickers`** are objects that are capable of deciding where to place ticks. The default **tickers** typically do a pretty good job at placing ~5 to 8 ticks at a reasonable distance from one another.
#
# > But sometimes we need more control (eg. there are too many tick labels on the logit graph above).
#
# > Fortunately, matplotlib gives full control over ticks. We can even activate minor ticks.

# %%
x = np.linspace(-2, 2, 100)

# subplot 1 :
plt.figure(1, figsize=(15, 10))
plt.subplot(131) # 1 rows, 3 columns, 1st subplot =  left
plt.plot(x, x ** 3, 'r-')
plt.grid(True)
plt.title("Default ticks") # No ticks have been set up

# subplot 2 :
ax = plt.subplot(132)  # 1 rows, 3 columns, 2nd subplot =  middle
plt.plot(x, x ** 3, 'b+')
ax.xaxis.set_ticks(np.arange(-2, 2, 1)) # -2 >--> 2 >--> 1
plt.grid(True)
plt.title("Manual ticks on the x-axis") # yaxis haven't been set up.

# subplot 3 :
ax = plt.subplot(133)  # 1 rows, 3 columns, 3th subplot =  right
plt.plot(x, x ** 3, 'g<')
plt.minorticks_on()
ax.tick_params(axis='x', which='minor', bottom='off')
ax.xaxis.set_ticks([-2, 0, 1, 2]) # -2 >--> 0 >--> 1 >--> 2 
ax.yaxis.set_ticks(np.arange(-5, 5, 1))
ax.yaxis.set_ticklabels(["min", -4, -3, -2, -1, 0, 1, 2, 3, "max"]) # min >--> -4 >--> ... >--> 3 >--> max
plt.title("Manual ticks and tick labels\n(plus minor ticks) on the y-axis")

plt.grid(True)
plt.show()

# %% [markdown]
# ### 1️⃣1️⃣   `Polar projection` :
# > Drawing a polar graph is as easy as setting the **`projection`** attribute to **`polar`** when creating the subplot.

# %%
radius = 1
theta = np.linspace(0, 2 * np.pi * radius, 1000)

plt.subplot(111, projection='polar')
plt.plot(theta, np.sin(5 * theta), "g-") # the curve function in green is that of the sinus.
plt.plot(theta, 0.5 * np.cos(20 * theta), "b-") # the curve function in blue is that of the cosine.
plt.show()

# %% [markdown]
# ### 1️⃣2️⃣   `3D projection` :
# > Plotting **`3D graphs`** is quite straightforward. We need to import **`Axes3D`**, which registers the **`3d`** projection. Then create a subplot setting the **`projection`** to **`3d`**. This returns an **`Axes3DSubplot`** object, which you can use to call **`plot_surface`**, giving **x**, **y**, and **z** coordinates, plus optional attributes.
#
# > **`.numpy.meshgrid()`** function is used to create a rectangular grid out of two given one-dimensional arrays representing the Cartesian indexing or Matrix indexing.

# %% [markdown]
# > We want to draw the curve of the function : **$z = sin(\sqrt{x^{2}+y^{2}})$**

# %%
from mpl_toolkits.mplot3d import Axes3D

x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)

X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X ** 2 + Y ** 2))

figure = plt.figure(1, figsize=(15, 6))
subplot3d = plt.subplot(111, projection='3d')
surface = subplot3d.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=matplotlib.cm.coolwarm, linewidth=0.1)
plt.show()

# %% [markdown]
# Another way to display this same data is *via* a contour plot.

# %%
# Vue from above :
plt.contourf(X, Y, Z, cmap=matplotlib.cm.coolwarm)
plt.colorbar()
plt.show()

# %% [markdown]
# ### 1️⃣3️⃣   ` Scatter plot` :
# > To draw a scatter plot, we simply provide the **x** and **y** coordinates of the points.

# %%
from numpy.random import rand

x, y = rand(2, 100)
plt.scatter(x, y)
plt.show()

# %% [markdown]
# > We may also optionally provide the scale of each point.

# %%
x, y, scale = rand(3, 100)
scale *= 100
plt.scatter(x, y, s=scale)
plt.show()

# %% [markdown]
# > And as usual there are a number of other attributes we can set, such as the fill and edge colors and the alpha level.

# %%
for color in ['red', 'green', 'blue', 'yellow', 'gray']:
    n = 50
    x, y = rand(2, n)
    scale = 500.0 * rand(n) ** 5
    plt.scatter(x, y, s=scale, c=color, alpha=0.3, edgecolors='blue')

plt.grid(True)
plt.show()

# %% [markdown]
# ### 1️⃣4️⃣   `Lines` :
# > We can draw lines simply using the **`plot`** function, as we have done so far.
# > However, it is often convenient to create a utility function that plots a (seemingly) infinite line across the graph, given a slope and an intercept.
# > We can also use the **`hlines`** and **`vlines`** functions that plot horizontal and vertical line segments.
# For example:

# %%
from numpy.random import randn


def plot_line(axis, slope, intercept, **kargs):
    xmin, xmax = axis.get_xlim()
    plt.plot([xmin, xmax], [xmin * slope + intercept, xmax * slope + intercept], **kargs)


x = randn(1000)
y = 0.5 * x + 5 + randn(1000) * 2
plt.axis([-2.5, 2.5, -5, 15])
plt.scatter(x, y, alpha=0.2)

# Red lines :
plt.plot(1, 0, "ro")
plt.vlines(1, -5, 0, color="red")
plt.hlines(0, -2.5, 1, color="red")

# Magneta line :
plot_line(axis=plt.gca(), slope=0.7, intercept=10, color="magenta")

plt.grid(True)
plt.show()

# %% [markdown]
# ### 1️⃣5️⃣   `Histograms` :
# > **`Histogram`** is a display of statistical information that uses rectangles to show the frequency of data items in successive numerical intervals of equal size.

# %%
with plt.xkcd():
    data = [1, 1.1, 1.8, 2, 2.1, 3.2, 3, 3, 3, 3]
    plt.subplot(121) # 2 rows, 1 column, 1st subplot
    plt.hist(data, bins=10, rwidth=0.8)
    plt.xlabel("Value")
    plt.ylabel("Frequency")

    plt.subplot(122) # 2 rows, 1 column, 2nd subplot
    plt.hist(data, bins=[1, 1.5, 2, 2.5, 3], rwidth=0.95)
    plt.xlabel("Value")

    plt.show()

# %%
data1 = np.random.randn(400)
plt.hist(data1, bins=5, color='g', alpha=0.75,
         label='bar hist')  # default histtype='bar'

data2 = np.random.randn(500) + 3
plt.hist(data2, color='b', alpha=0.65,
         histtype='stepfilled', label='stepfilled hist')

data3 = np.random.randn(450) + 6
plt.hist(data3, color='r', histtype='step',
         label='step hist')

data4a = np.random.randn(200) + 9
data4b = np.random.randn(100) + 10
plt.hist((data4a, data4b), color=('r', 'm'), alpha=0.55,
         histtype='barstacked', label=('barstacked a', 'barstacked b'))

plt.xlabel("Value")
plt.ylabel("Frequency")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 1️⃣6️⃣   `Images` :
# > Reading, generating and plotting images in **`matplotlib`** is quite straightforward.
#
# > To read an **image**, we just import the **`matplotlib.image`** module, and call its **`imread`** function, passing it the file name (or file object). This returns the image data, as a NumPy array.
#
# > Let's try this with the **`my_square_function.png`** image we saved earlier.

# %%
import matplotlib.image as mpimg

img = mpimg.imread('my_square_function.png')
print(img.shape, img.dtype)
# Out:
# (288, 432, 4) float32

# %% [markdown]
# > We have loaded a **288x432** image. Each pixel is represented by a 4-element array:
# > - **`red`**, **`green`**, **`blue`**, and **`alpha levels`**, stored as **32-bit floats** between **0** and **1**.
#
# > Now all we need to do is to call `imshow`:

# %%
plt.imshow(img)
plt.show()

# %% [markdown]
# > Tadaaa 😊 ! You may want to **hide the axes** when you are displaying an image :

# %%
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# > It's just as easy to generate your own image :

# %%
img = np.arange(1000*1000).reshape(1000, 1000)
print(img)

plt.imshow(img)
plt.show()
# Out:
# [[     0      1      2 ...    997    998    999]
#  [  1000   1001   1002 ...   1997   1998   1999]
#  [  2000   2001   2002 ...   2997   2998   2999]
#  ...
#  [997000 997001 997002 ... 997997 997998 997999]
#  [998000 998001 998002 ... 998997 998998 998999]
#  [999000 999001 999002 ... 999997 999998 999999]]

# %% [markdown]
# > As we did not provide RGB levels, the **`imshow`** function automatically maps values to a color gradient.
#
# > By default, the color gradient goes from **blue** (for low values) to **red** (for high values), but you can select another color map.  For example:

# %%
plt.imshow(img, cmap="hot")
plt.show()

# %% [markdown]
# > We can also generate an **RGB** image directly:

# %%
img = np.empty((20, 30, 3))
img[:, :10] = [0, 0, 0.6]
img[:, 10:20] = [1, 1, 1]
img[:, 20:] = [0.6, 0, 0]
plt.imshow(img)
plt.show()

# %% [markdown]
# > Since the **`img`** array is just quite small **`20x30`**, when the **`imshow`** function displays it, it grows the image to the figure's size. By default it uses [bilinear interpolation](https://en.wikipedia.org/wiki/Bilinear_interpolation) to fill the added pixels. This is why the edges look blurry.
# You can select another interpolation algorithm, such as copying the color of the nearest pixel:

# %%
plt.imshow(img, interpolation="nearest")
plt.show()

# %% [markdown]
# ### 1️⃣7️⃣   `Animations` :
# > Although **`matplotlib`** is mostly used to generate images, it is also capable of displaying animations, depending on the Backend we use. 4
#
# > In a **`Jupyter notebook`**, we need to use the **`nbagg`** backend to use interactive matplotlib features, including animations. We also need to import **`matplotlib.animation`**.

# %%
# %matplotlib nbagg
import matplotlib.animation as animation

# %% [markdown]
# > In this example, we start by creating data points, then we create an empty plot, we define the update function that will be called at every iteration of the animation, and finally we add an animation to the plot by creating a **`FuncAnimation`** instance.
#
# > The **`FuncAnimation`** constructor takes a figure, an update function and optional arguments. We specify that we want a 100-frame long animation, with 20ms between each frame. At each iteration, **`FuncAnimation`** calls our update function and passes it the frame number **`num`** (from 0 to 99 in our case) followed by the extra arguments that we specified with **`fargs`**.
#
# > Our update function simply sets the line data to be the first `num` data points (so the data gets drawn gradually), and just for fun we also add a small random number to each data point so that the line appears to wiggle.

# %%
x = np.linspace(-1, 1, 100)
y = np.sin(x ** 2 * 25)
data = np.array([x, y])

fig = plt.figure()
line, = plt.plot([], [], "r-")  # start with an empty plot
plt.axis([-1.1, 1.1, -1.1, 1.1])
plt.plot([-0.5, 0.5], [0, 0], "b-", [0, 0], [-0.5, 0.5], "b-", 0, 0, "ro")
plt.grid(True)
plt.title("Marvelous animation")


# this function will be called at every iteration
def update_line(num, data, line):
    line.set_data(data[..., :num] + np.random.rand(2, num) / 25)  # we only plot the first `num` data points.
    return line,


line_ani = animation.FuncAnimation(fig, update_line, frames=100, fargs=(data, line), interval=67)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# ### 1️⃣8️⃣   `What next?` :
# > Now you know all the basics of matplotlib, but there are many more options available. The best way to learn more, is to visit the [gallery](http://matplotlib.org/gallery.html), look at the images, choose a plot that you are interested in, then just copy the code in a Jupyter notebook and play around with it.
